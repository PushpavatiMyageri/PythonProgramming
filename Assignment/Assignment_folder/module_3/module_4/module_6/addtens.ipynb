# %%
import tensorflow as tf
a = tf.constant(10)
b = tf.constant(20)
tf.add(a,b)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\__init__.py:214, in __getattr__(name)
#     213 try:
# --> 214     return globals()[name]
#     215 except KeyError:
#
# KeyError: '_lib'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\Users\User\Desktop\python_programs\Assignment_folder\module_3\module_4\module_6\addtens.ipynb Cell 1 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/python_programs/Assignment_folder/module_3/module_4/module_6/addtens.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import tensorflow as tf
# ...
